# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafterbang/tkc_258-271/blob/main/BuildModel_258_271.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/S7/TKC
# Out:
# /content/drive/MyDrive/Colab Notebooks/S7/TKC

# %%
# %ls
# Out:
# chest-xray-covid19-pneumonia.zip  COVID-19_Radiography_Dataset/  kaggle.json
# covid19-radiography-database.zip  Data/                          model.png

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from glob import glob
from PIL import Image
import os
import random
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Model
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model,load_model
from tensorflow.keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPooling2D,MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical # convert to one-hot-encoding
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator,array_to_img
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping,ModelCheckpoint
from tensorflow.keras.metrics import PrecisionAtRecall,Recall

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# %%
from numpy.random import seed
seed(0)

# %%
tf.random.set_seed(0)

# %%
path = '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train'

diag_code_dict = {
    'COVID19': 0,
    'NORMAL': 1,
    'PNEUMONIA': 2}

diag_title_dict = {
    'COVID19': 'Covid-19',
    'NORMAL': 'Healthy',
    'PNEUMONIA': 'Pneumonia'}

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in glob(os.path.join(path, '*','*.jpg'))}

imageid_path_dict
# Out:
# {'COVID19(0)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(0).jpg',
#  'COVID19(1)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(1).jpg',
#  'COVID19(10)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(10).jpg',
#  'COVID19(100)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(100).jpg',
#  'COVID19(101)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(101).jpg',
#  'COVID19(102)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(102).jpg',
#  'COVID19(103)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(103).jpg',
#  'COVID19(104)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(104).jpg',
#  'COVID19(105)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(105).jpg',
#  'COVID19(106)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(106).jpg',
#  'COVID19(107)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(107).jpg',
#  'COVID19(108)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(108).jpg',
#  'COVID19(109)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(109).jpg',
#  'COVID19(11)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(11).jpg',
#  'COVID19(110)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(110).jpg',
#  'COVID19(111)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(111).jpg',
#  'COVID19(112)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(112).jpg',
#  'COVID19(113)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(113).jpg',
#  'COVID19(114)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(114).jpg',
#  'COVID19(115)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(115).jpg',
#  'COVID19(116)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(116).jpg',
#  'COVID19(117)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(117).jpg',
#  'COVID19(118)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(118).jpg',
#  'COVID19(119)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(119).jpg',
#  'COVID19(12)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(12).jpg',
#  'COVID19(120)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(120).jpg',
#  'COVID19(121)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(121).jpg',
#  'COVID19(122)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(122).jpg',
#  'COVID19(123)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(123).jpg',
#  'COVID19(124)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(124).jpg',
#  'COVID19(125)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(125).jpg',
#  'COVID19(126)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(126).jpg',
#  'COVID19(127)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(127).jpg',
#  'COVID19(128)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(128).jpg',
#  'COVID19(129)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(129).jpg',
#  'COVID19(13)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(13).jpg',
#  'COVID19(130)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(130).jpg',
#  'COVID19(131)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(131).jpg',
#  'COVID19(132)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(132).jpg',
#  'COVID19(133)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(133).jpg',
#  'COVID19(134)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(134).jpg',
#  'COVID19(135)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(135).jpg',
#  'COVID19(136)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(136).jpg',
#  'COVID19(137)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(137).jpg',
#  'COVID19(138)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(138).jpg',
#  'COVID19(139)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(139).jpg',
#  'COVID19(14)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(14).jpg',
#  'COVID19(140)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(140).jpg',
#  'COVID19(141)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(141).jpg',
#  'COVID19(142)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(142).jpg',
#  'COVID19(143)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(143).jpg',
#  'COVID19(144)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(144).jpg',
#  'COVID19(145)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(145).jpg',
#  'COVID19(146)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19(146).jpg',
#  'COVID19(147)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/COVID19/COVID19
': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(1241).jpg',
#  'NORMAL(1242)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(1242).jpg',
#  'NORMAL(1243)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(1243).jpg',
#  'NORMAL(1244)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(1244).jpg',
#  'NORMAL(1245)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(1245).jpg',
#  'NORMAL(1246)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(1246).jpg',
#  'NORMAL(1247)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(1247).jpg',
# ...
#  'NORMAL(44)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(44).jpg',
#  'NORMAL(440)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(440).jpg',
#  'NORMAL(441)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(441).jpg',
#  'NORMAL(442)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(442).jpg',
#  'NORMAL(443)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(443).jpg',
#  'NORMAL(444)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(444).jpg',
#  'NORMAL(445)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(445).jpg',
#  'NORMAL(446)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(446).jpg',
#  'NORMAL(447)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(447).jpg',
#  'NORMAL(448)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(448).jpg',
#  'NORMAL(449)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(449).jpg',
#  'NORMAL(45)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(45).jpg',
#  'NORMAL(450)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(450).jpg',
#  'NORMAL(451)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(451).jpg',
#  'NORMAL(452)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(452).jpg',
#  'NORMAL(453)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(453).jpg',
#  'NORMAL(454)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(454).jpg',
#  'NORMAL(455)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(455).jpg',
#  'NORMAL(456)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(456).jpg',
#  'NORMAL(457)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(457).jpg',
#  'NORMAL(458)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(458).jpg',
#  'NORMAL(459)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(459).jpg',
#  'NORMAL(46)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(46).jpg',
#  'NORMAL(460)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(460).jpg',
#  'NORMAL(461)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(461).jpg',
#  'NORMAL(462)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(462).jpg',
#  'NORMAL(463)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(463).jpg',
#  'NORMAL(464)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(464).jpg',
#  'NORMAL(465)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(465).jpg',
#  'NORMAL(466)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(466).jpg',
#  'NORMAL(467)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(467).jpg',
#  'NORMAL(468)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(468).jpg',
#  'NORMAL(469)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(469).jpg',
#  'NORMAL(47)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(47).jpg',
#  'NORMAL(470)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(470).jpg',
#  'NORMAL(471)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(471).jpg',
#  'NORMAL(472)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(472).jpg',
#  'NORMAL(473)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(473).jpg',
#  'NORMAL(474)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(474).jpg',
#  'NORMAL(475)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(475).jpg',
#  'NORMAL(476)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(476).jpg',
#  'NORMAL(477)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(477).jpg',
#  'NORMAL(478)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(478).jpg',
#  'NORMAL(479)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(479).jpg',
#  'NORMAL(48)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(48).jpg',
#  'NORMAL(480)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(480).jpg',
#  'NORMAL(481)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(481).jpg',
#  'NORMAL(482)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(482).jpg',
#  'NORMAL(483)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(483).jpg',
#  'NORMAL(484)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(484).jpg',
#  'NORMAL(485)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(485).jpg',
#  'NORMAL(486)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(486).jpg',
#  'NORMAL(487)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(487).jpg',
#  'NORMAL(488)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(488).jpg',
#  'NORMAL(489)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(489).jpg',
#  'NORMAL(49)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(49).jpg',
#  'NORMAL(490)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(490).jpg',
#  'NORMAL(491)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(491).jpg',
#  'NORMAL(492)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(492).jpg',
#  'NORMAL(493)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(493).jpg',
#  'NORMAL(494)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(494).jpg',
#  'NORMAL(495)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(495).jpg',
#  'NORMAL(496)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(496).jpg',
#  'NORMAL(497)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(497).jpg',
#  'NORMAL(498)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(498).jpg',
#  'NORMAL(499)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(499).jpg',
#  'NORMAL(5)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(5).jpg',
#  'NORMAL(50)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(50).jpg',
#  'NORMAL(500)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(500).jpg',
#  'NORMAL(501)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(501).jpg',
#  'NORMAL(502)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(502).jpg',
#  'NORMAL(503)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(503).jpg',
#  'NORMAL(504)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(504).jpg',
#  'NORMAL(505)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(505).jpg',
#  'NORMAL(506)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(506).jpg',
#  'NORMAL(507)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(507).jpg',
#  'NORMAL(508)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(508).jpg',
#  'NORMAL(509)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(509).jpg',
#  'NORMAL(51)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(51).jpg',
#  'NORMAL(510)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(510).jpg',
#  'NORMAL(511)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(511).jpg',
#  'NORMAL(512)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(512).jpg',
#  'NORMAL(513)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(513).jpg',
#  'NORMAL(514)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(514).jpg',
#  'NORMAL(515)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(515).jpg',
#  'NORMAL(516)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(516).jpg',
#  'NORMAL(517)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(517).jpg',
#  'NORMAL(518)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(518).jpg',
#  'NORMAL(519)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(519).jpg',
#  'NORMAL(52)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(52).jpg',
#  'NORMAL(520)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(520).jpg',
#  'NORMAL(521)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(521).jpg',
#  'NORMAL(522)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(522).jpg',
#  'NORMAL(523)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(523).jpg',
#  'NORMAL(524)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(524).jpg',
#  'NORMAL(525)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(525).jpg',
#  'NORMAL(526)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(526).jpg',
#  'NORMAL(527)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(527).jpg',
#  'NORMAL(528)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(528).jpg',
#  'NORMAL(529)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(529).jpg',
#  'NORMAL(53)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(53).jpg',
#  'NORMAL(530)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(530).jpg',
#  'NORMAL(531)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(531).jpg',
#  'NORMAL(532)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(532).jpg',
#  'NORMAL(533)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(533).jpg',
#  'NORMAL(534)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(534).jpg',
#  'NORMAL(535)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(535).jpg',
#  'NORMAL(536)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(536).jpg',
#  'NORMAL(537)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(537).jpg',
#  'NORMAL(538)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(538).jpg',
#  'NORMAL(539)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(539).jpg',
#  'NORMAL(54)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(54).jpg',
#  'NORMAL(540)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(540).jpg',
#  'NORMAL(541)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(541).jpg',
#  'NORMAL(542)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(542).jpg',
#  'NORMAL(543)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(543).jpg',
#  'NORMAL(544)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(544).jpg',
#  'NORMAL(545)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(545).jpg',
#  'NORMAL(546)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(546).jpg',
#  'NORMAL(547)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(547).jpg',
#  'NORMAL(548)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(548).jpg',
#  'NORMAL(549)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(549).jpg',
#  'NORMAL(55)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(55).jpg',
#  'NORMAL(550)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(550).jpg',
#  'NORMAL(551)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(551).jpg',
#  'NORMAL(552)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(552).jpg',
#  'NORMAL(553)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(553).jpg',
#  'NORMAL(554)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(554).jpg',
#  'NORMAL(555)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(555).jpg',
#  'NORMAL(556)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(556).jpg',
#  'NORMAL(557)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(557).jpg',
#  'NORMAL(558)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(558).jpg',
#  'NORMAL(559)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(559).jpg',
#  'NORMAL(56)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(56).jpg',
#  'NORMAL(560)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(560).jpg',
#  'NORMAL(561)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(561).jpg',
#  'NORMAL(562)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(562).jpg',
#  'NORMAL(563)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(563).jpg',
#  'NORMAL(564)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(564).jpg',
#  'NORMAL(565)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(565).jpg',
#  'NORMAL(566)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(566).jpg',
#  'NORMAL(567)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(567).jpg',
#  'NORMAL(568)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(568).jpg',
#  'NORMAL(569)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(569).jpg',
#  'NORMAL(57)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(57).jpg',
#  'NORMAL(570)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(570).jpg',
#  'NORMAL(571)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(571).jpg',
#  'NORMAL(572)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(572).jpg',
#  'NORMAL(573)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(573).jpg',
#  'NORMAL(574)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(574).jpg',
#  'NORMAL(575)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(575).jpg',
#  'NORMAL(576)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(576).jpg',
#  'NORMAL(577)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(577).jpg',
#  'NORMAL(578)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(578).jpg',
#  'NORMAL(579)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(579).jpg',
#  'NORMAL(58)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(58).jpg',
#  'NORMAL(580)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(580).jpg',
#  'NORMAL(581)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(581).jpg',
#  'NORMAL(582)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(582).jpg',
#  'NORMAL(583)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(583).jpg',
#  'NORMAL(584)': '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train/NORMAL/NORMAL(584).jpg',
#  ...}

# %%
test_path = '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/test'
train_path = '/content/drive/MyDrive/Colab Notebooks/S7/TKC/Data/train'

classes = ["COVID19", "NORMAL", "PNEUMONIA"]
num_classes = len(classes)
batch_size = 16

train_datagen = ImageDataGenerator(rescale=1./255,
                                  rotation_range=20,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  horizontal_flip=True, validation_split=0.001)

test_datagen = ImageDataGenerator(rescale=1./255,
                                 validation_split=0.999)

train_gen = train_datagen.flow_from_directory(directory=train_path,
                                             target_size=(299, 299),
                                             class_mode='categorical',
                                             subset='training',
                                             shuffle=True, classes=classes,
                                             batch_size=batch_size,
                                             color_mode="grayscale")

test_gen = test_datagen.flow_from_directory(directory=test_path,
                                             target_size=(299, 299),
                                             class_mode='categorical',
                                             subset='validation',
                                             shuffle=False, classes=classes,
                                             batch_size=batch_size,
                                             color_mode="grayscale")
# Out:
# Found 5140 images belonging to 3 classes.
# Found 1285 images belonging to 3 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation='relu', padding='Same', input_shape=(299, 299, 1)))
model.add(BatchNormalization())

################

model.add(Conv2D(64, (3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#################

model.add(Conv2D(64, (3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3,3), activation='relu', padding='Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#################

model.add(Flatten())

model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.25))

#Output 
model.add(BatchNormalization())
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 299, 299, 32)      320
#
#  batch_normalization_9 (Batc  (None, 299, 299, 32)     128
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 299, 299, 64)      18496
#
#  batch_normalization_10 (Bat  (None, 299, 299, 64)     256
#  chNormalization)
#
#  average_pooling2d_4 (Averag  (None, 149, 149, 64)     0
#  ePooling2D)
#
#  dropout_5 (Dropout)         (None, 149, 149, 64)      0
#
#  conv2d_9 (Conv2D)           (None, 149, 149, 64)      36928
#
#  batch_normalization_11 (Bat  (None, 149, 149, 64)     256
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 149, 149, 64)      36928
#
#  batch_normalization_12 (Bat  (None, 149, 149, 64)     256
#  chNormalization)
#
#  average_pooling2d_5 (Averag  (None, 74, 74, 64)       0
#  ePooling2D)
#
#  dropout_6 (Dropout)         (None, 74, 74, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 74, 74, 64)        36928
#
#  batch_normalization_13 (Bat  (None, 74, 74, 64)       256
#  chNormalization)
#
#  average_pooling2d_6 (Averag  (None, 37, 37, 64)       0
#  ePooling2D)
#
#  dropout_7 (Dropout)         (None, 37, 37, 64)        0
#
#  conv2d_12 (Conv2D)          (None, 37, 37, 64)        36928
#
#  batch_normalization_14 (Bat  (None, 37, 37, 64)       256
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 37, 37, 64)        36928
#
#  batch_normalization_15 (Bat  (None, 37, 37, 64)       256
#  chNormalization)
#
#  average_pooling2d_7 (Averag  (None, 18, 18, 64)       0
#  ePooling2D)
#
#  dropout_8 (Dropout)         (None, 18, 18, 64)        0
#
#  flatten_1 (Flatten)         (None, 20736)             0
#
#  batch_normalization_16 (Bat  (None, 20736)            82944
#  chNormalization)
#
#  dense_2 (Dense)             (None, 128)               2654336
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  batch_normalization_17 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2,943,299
# Trainable params: 2,900,739
# Non-trainable params: 42,560
# _________________________________________________________________

# %%
opt = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.1, amsgrad=False)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from tensorflow import keras

keras.utils.plot_model(model)

# %%
epochs=20

#callback

history = model.fit(train_gen,
                    steps_per_epoch=len(train_gen) // batch_size,
                    validation_steps=len(test_gen) // batch_size,
                    validation_data=test_gen, epochs=epochs)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 179s 8s/step - loss: 1.5438 - acc: 0.5000 - val_loss: 0.5019 - val_acc: 1.0000
# Epoch 2/20
# 20/20 [==============================] - 42s 2s/step - loss: 0.8642 - acc: 0.6562 - val_loss: 0.5206 - val_acc: 1.0000
# Epoch 3/20
# 20/20 [==============================] - 46s 2s/step - loss: 0.7191 - acc: 0.7375 - val_loss: 0.5352 - val_acc: 1.0000
# Epoch 4/20
# 20/20 [==============================] - 38s 2s/step - loss: 0.7410 - acc: 0.7375 - val_loss: 0.3832 - val_acc: 1.0000
# Epoch 5/20
# 20/20 [==============================] - 39s 2s/step - loss: 0.7862 - acc: 0.6938 - val_loss: 0.1760 - val_acc: 1.0000
# Epoch 6/20
# 20/20 [==============================] - 35s 2s/step - loss: 0.7539 - acc: 0.7156 - val_loss: 0.3577 - val_acc: 1.0000
# Epoch 7/20
# 20/20 [==============================] - 36s 2s/step - loss: 0.6520 - acc: 0.7662 - val_loss: 0.3402 - val_acc: 1.0000
# Epoch 8/20
# 20/20 [==============================] - 40s 2s/step - loss: 0.6408 - acc: 0.7469 - val_loss: 0.2204 - val_acc: 1.0000
# Epoch 9/20
# 20/20 [==============================] - 36s 2s/step - loss: 0.6284 - acc: 0.7719 - val_loss: 0.1495 - val_acc: 1.0000
# Epoch 10/20
# 20/20 [==============================] - 31s 2s/step - loss: 0.6750 - acc: 0.7500 - val_loss: 0.2252 - val_acc: 1.0000
# Epoch 11/20
# 20/20 [==============================] - 30s 1s/step - loss: 0.5925 - acc: 0.7969 - val_loss: 0.1845 - val_acc: 1.0000
# Epoch 12/20
# 20/20 [==============================] - 35s 2s/step - loss: 0.4724 - acc: 0.8344 - val_loss: 0.1293 - val_acc: 1.0000
# Epoch 13/20
# 20/20 [==============================] - 31s 2s/step - loss: 0.5637 - acc: 0.8031 - val_loss: 0.1208 - val_acc: 1.0000
# Epoch 14/20
# 20/20 [==============================] - 28s 1s/step - loss: 0.5821 - acc: 0.7875 - val_loss: 0.0723 - val_acc: 1.0000
# Epoch 15/20
# 20/20 [==============================] - 32s 2s/step - loss: 0.4682 - acc: 0.8156 - val_loss: 0.0615 - val_acc: 1.0000
# Epoch 16/20
# 20/20 [==============================] - 59s 3s/step - loss: 0.5485 - acc: 0.8000 - val_loss: 0.0916 - val_acc: 0.9750
# Epoch 17/20
# 20/20 [==============================] - 27s 1s/step - loss: 0.5479 - acc: 0.7844 - val_loss: 0.0830 - val_acc: 0.9750
# Epoch 18/20
# 20/20 [==============================] - 27s 1s/step - loss: 0.4819 - acc: 0.8125 - val_loss: 0.1360 - val_acc: 0.9750
# Epoch 19/20
# 20/20 [==============================] - 29s 1s/step - loss: 0.4638 - acc: 0.8188 - val_loss: 0.2618 - val_acc: 0.8875
# Epoch 20/20
# 20/20 [==============================] - 29s 1s/step - loss: 0.5139 - acc: 0.8219 - val_loss: 0.2817 - val_acc: 0.8625

# %%
y_pred = model.predict(test_gen)

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
fig, axarr = plt.subplots(1,2, figsize=(15,5), sharex=True)

sns.set(style="ticks", font_scale = 1)
sns.despine(top=True, right=True, left=False, bottom=False)

historyDF = pd.DataFrame.from_dict(history.history)
ax = sns.lineplot(x = historyDF.index, y = history.history['acc'], ax=axarr[0], label="Training");
ax = sns.lineplot(x = historyDF.index, y = history.history['val_acc'], ax=axarr[0], label="Validation");
ax.set_ylabel('Accuracy')

ax = sns.lineplot(x = historyDF.index, y = history.history['loss'], ax=axarr[1], label="Training");
ax = sns.lineplot(x = historyDF.index, y = history.history['val_loss'], ax=axarr[1], label="Validation");
ax.set_ylabel('Loss')


axarr[0].set_title('Training and Validation metric recall')
axarr[1].set_title('Training and Validation loss')

for ax in axarr:
    ax.set_xlabel('Epochs')

plt.suptitle('Training and performance plots', fontsize=16, weight='bold');
fig.tight_layout(pad=3.0)
plt.show()

# %%
predictions = np.array(list(map(lambda x: np.argmax(x), y_pred)))

y_true=test_gen.classes

CMatrix = pd.DataFrame(confusion_matrix(y_true, predictions), columns=classes, index =classes)

plt.figure(figsize=(12, 6))
ax = sns.heatmap(CMatrix, annot = True, fmt = 'g' ,vmin = 0, vmax = 250,cmap = 'Blues')
ax.set_xlabel('Predicted',fontsize = 14,weight = 'bold')
ax.set_xticklabels(ax.get_xticklabels(),rotation =0);

ax.set_ylabel('Actual',fontsize = 14,weight = 'bold') 
ax.set_yticklabels(ax.get_yticklabels(),rotation =0);
ax.set_title('Confusion Matrix - Test Set',fontsize = 16,weight = 'bold',pad=20);

# %%
print(classification_report(y_true, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.89      0.63       115
#            1       0.00      0.00      0.00       316
#            2       0.71      0.89      0.79       854
#
#     accuracy                           0.67      1285
#    macro avg       0.40      0.59      0.47      1285
# weighted avg       0.52      0.67      0.58      1285
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
acc = accuracy_score(y_true, predictions)

results_all = precision_recall_fscore_support(y_true, predictions, average='macro', zero_division=1)
results_class = precision_recall_fscore_support(y_true, predictions, average=None, zero_division=1)

metric_columns = ['Precision','Recall', 'F1-Score','S']
all_df = pd.concat([pd.DataFrame(list(results_class)).T,pd.DataFrame(list(results_all)).T])
all_df.columns = metric_columns
all_df.index = ['COVID','Normal', 'Viral Pneumonia','Total']

def metrics_plot(df,metric):
    plt.figure(figsize=(22,10))
    ax = sns.barplot(data =df, x=df.index, y = metric,palette = "Blues_d")
    #Bar Labels
    for p in ax.patches:
        ax.annotate("%.1f%%" % (100*p.get_height()), (p.get_x() + p.get_width() / 2., abs(p.get_height())),
        ha='center', va='bottom', color='black', xytext=(-3, 5),rotation = 'horizontal',textcoords='offset points')
    sns.despine(top=True, right=True, left=True, bottom=False)
    ax.set_xlabel('Class',fontsize = 14,weight = 'bold')
    ax.set_ylabel(metric,fontsize = 14,weight = 'bold')
    ax.set(yticklabels=[])
    ax.axes.get_yaxis().set_visible(False) 
    plt.title(metric+ ' Results per Class', fontsize = 16,weight = 'bold');

metrics_plot(all_df, 'Precision')#Results by Class
metrics_plot(all_df, 'Recall')#Results by Class
metrics_plot(all_df, 'F1-Score')#Results by Class

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/S7/TKC/model.h5')
